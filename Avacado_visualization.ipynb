# %% [markdown]
# # githublink:https://github.com/Ankurrsingh/Avacoado_ML

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Avocado.csv')

# %%
df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# 3  2015  Albany
# 4  2015  Albany

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  object
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 1.9+ MB

# %%
df.isna().sum()
# Out:
# Unnamed: 0      0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
df.describe()
# Out:
#          Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  18249.000000  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04
# mean      24.232232      1.405978  8.506440e+05  2.930084e+05  2.951546e+05
# std       15.481045      0.402677  3.453545e+06  1.264989e+06  1.204120e+06
# min        0.000000      0.440000  8.456000e+01  0.000000e+00  0.000000e+00
# 25%       10.000000      1.100000  1.083858e+04  8.540700e+02  3.008780e+03
# 50%       24.000000      1.370000  1.073768e+05  8.645300e+03  2.906102e+04
# 75%       38.000000      1.660000  4.329623e+05  1.110202e+05  1.502069e+05
# max       52.000000      3.250000  6.250565e+07  2.274362e+07  2.047057e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000
# mean   2.283974e+04  2.396392e+05  1.821947e+05  5.433809e+04    3106.426507
# std    1.074641e+05  9.862424e+05  7.461785e+05  2.439660e+05   17692.894652
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00       0.000000
# 25%    0.000000e+00  5.088640e+03  2.849420e+03  1.274700e+02       0.000000
# 50%    1.849900e+02  3.974383e+04  2.636282e+04  2.647710e+03       0.000000
# 75%    6.243420e+03  1.107834e+05  8.333767e+04  2.202925e+04     132.500000
# max    2.546439e+06  1.937313e+07  1.338459e+07  5.719097e+06  551693.650000
#
#                year
# count  18249.000000
# mean    2016.147899
# std        0.939938
# min     2015.000000
# 25%     2015.000000
# 50%     2016.000000
# 75%     2017.000000
# max     2018.000000

# %%
df.corr()
# Out:
#               Unnamed: 0  AveragePrice  Total Volume      4046      4225  \
# Unnamed: 0      1.000000     -0.133008      0.014035  0.017628  0.019829
# AveragePrice   -0.133008      1.000000     -0.192752 -0.208317 -0.172928
# Total Volume    0.014035     -0.192752      1.000000  0.977863  0.974181
# 4046            0.017628     -0.208317      0.977863  1.000000  0.926110
# 4225            0.019829     -0.172928      0.974181  0.926110  1.000000
# 4770            0.041752     -0.179446      0.872202  0.833389  0.887855
# Total Bags     -0.002219     -0.177088      0.963047  0.920057  0.905787
# Small Bags      0.000347     -0.174730      0.967238  0.925280  0.916031
# Large Bags     -0.009196     -0.172940      0.880640  0.838645  0.810015
# XLarge Bags    -0.011546     -0.117592      0.747157  0.699377  0.688809
# year           -0.171667      0.093197      0.017193  0.003353 -0.009559
#
#                   4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# Unnamed: 0    0.041752   -0.002219    0.000347   -0.009196    -0.011546
# AveragePrice -0.179446   -0.177088   -0.174730   -0.172940    -0.117592
# Total Volume  0.872202    0.963047    0.967238    0.880640     0.747157
# 4046          0.833389    0.920057    0.925280    0.838645     0.699377
# 4225          0.887855    0.905787    0.916031    0.810015     0.688809
# 4770          1.000000    0.792314    0.802733    0.698471     0.679861
# Total Bags    0.792314    1.000000    0.994335    0.943009     0.804233
# Small Bags    0.802733    0.994335    1.000000    0.902589     0.806845
# Large Bags    0.698471    0.943009    0.902589    1.000000     0.710858
# XLarge Bags   0.679861    0.804233    0.806845    0.710858     1.000000
# year         -0.036531    0.071552    0.063915    0.087891     0.081033
#
#                   year
# Unnamed: 0   -0.171667
# AveragePrice  0.093197
# Total Volume  0.017193
# 4046          0.003353
# 4225         -0.009559
# 4770         -0.036531
# Total Bags    0.071552
# Small Bags    0.063915
# Large Bags    0.087891
# XLarge Bags   0.081033
# year          1.000000

# %%
import seaborn as sns

# %%
sns.pairplot(df)

# %%
sns.countplot('type',data = df)

# %%
sns.barplot(x = 'year',y = 'Total Volume',data = df,palette= 'Blues')

# %%
sns.heatmap(df.corr())

# %%
sns.boxplot('year','AveragePrice',data = df)

# %%
sns.distplot(df['AveragePrice'])

# %%
sns.lineplot('Date','AveragePrice',hue = 'year',data = df)

# %%
sns.lineplot('Date','Total Volume',hue = 'year',data = df)

# %%
sns.swarmplot('Date','AveragePrice',data = df,hue = 'type')

# %%
sns.catplot('year','Total Volume',data = df)

# %%
sns.catplot('year','Total Bags',data = df)

# %%
df.head(5)
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# 3  2015  Albany
# 4  2015  Albany

# %%
df=df.drop('Unnamed: 0',axis=1)

# %%
df.head(2)
# Out:
#          Date  AveragePrice  Total Volume     4046      4225   4770  \
# 0  2015-12-27          1.33      64236.62  1036.74  54454.85  48.16
# 1  2015-12-20          1.35      54876.98   674.28  44638.81  58.33
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany

# %%
df["region"].unique()
# Out:
# array(['Albany', 'Atlanta', 'BaltimoreWashington', 'Boise', 'Boston',
#        'BuffaloRochester', 'California', 'Charlotte', 'Chicago',
#        'CincinnatiDayton', 'Columbus', 'DallasFtWorth', 'Denver',
#        'Detroit', 'GrandRapids', 'GreatLakes', 'HarrisburgScranton',
#        'HartfordSpringfield', 'Houston', 'Indianapolis', 'Jacksonville',
#        'LasVegas', 'LosAngeles', 'Louisville', 'MiamiFtLauderdale',
#        'Midsouth', 'Nashville', 'NewOrleansMobile', 'NewYork',
#        'Northeast', 'NorthernNewEngland', 'Orlando', 'Philadelphia',
#        'PhoenixTucson', 'Pittsburgh', 'Plains', 'Portland',
#        'RaleighGreensboro', 'RichmondNorfolk', 'Roanoke', 'Sacramento',
#        'SanDiego', 'SanFrancisco', 'Seattle', 'SouthCarolina',
#        'SouthCentral', 'Southeast', 'Spokane', 'StLouis', 'Syracuse',
#        'Tampa', 'TotalUS', 'West', 'WestTexNewMexico'], dtype=object)

# %%
df=df.drop("Date",axis=1)

# %%
df.rename(columns = {'4046':'PUC4046_sold'}, inplace = True)

# %%
df.rename(columns = {'4225':'PUC4225_sold'}, inplace = True)

# %%
df.rename(columns = {'4770':'PUC4770_sold'}, inplace = True)

# %%
df.head(3)
# Out:
#    AveragePrice  Total Volume  PUC4046_sold  PUC4225_sold  PUC4770_sold  \
# 0          1.33      64236.62       1036.74      54454.85         48.16
# 1          1.35      54876.98        674.28      44638.81         58.33
# 2          0.93     118220.22        794.70     109149.67        130.50
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany

# %%
df["type"].unique()
# Out:
# array(['conventional', 'organic'], dtype=object)

# %%
from sklearn.preprocessing import LabelBinarizer

# %%
lb=LabelBinarizer()

# %%
df["type"]=lb.fit_transform(df.type)

# %%
df["type"].unique()
# Out:
# array([0, 1])

# %%
df.corr()
# Out:
#               AveragePrice  Total Volume  PUC4046_sold  PUC4225_sold  \
# AveragePrice      1.000000     -0.192752     -0.208317     -0.172928
# Total Volume     -0.192752      1.000000      0.977863      0.974181
# PUC4046_sold     -0.208317      0.977863      1.000000      0.926110
# PUC4225_sold     -0.172928      0.974181      0.926110      1.000000
# PUC4770_sold     -0.179446      0.872202      0.833389      0.887855
# Total Bags       -0.177088      0.963047      0.920057      0.905787
# Small Bags       -0.174730      0.967238      0.925280      0.916031
# Large Bags       -0.172940      0.880640      0.838645      0.810015
# XLarge Bags      -0.117592      0.747157      0.699377      0.688809
# type              0.615845     -0.232434     -0.225819     -0.232289
# year              0.093197      0.017193      0.003353     -0.009559
#
#               PUC4770_sold  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# AveragePrice     -0.179446   -0.177088   -0.174730   -0.172940    -0.117592
# Total Volume      0.872202    0.963047    0.967238    0.880640     0.747157
# PUC4046_sold      0.833389    0.920057    0.925280    0.838645     0.699377
# PUC4225_sold      0.887855    0.905787    0.916031    0.810015     0.688809
# PUC4770_sold      1.000000    0.792314    0.802733    0.698471     0.679861
# Total Bags        0.792314    1.000000    0.994335    0.943009     0.804233
# Small Bags        0.802733    0.994335    1.000000    0.902589     0.806845
# Large Bags        0.698471    0.943009    0.902589    1.000000     0.710858
# XLarge Bags       0.679861    0.804233    0.806845    0.710858     1.000000
# type             -0.210027   -0.217788   -0.220535   -0.193177    -0.175483
# year             -0.036531    0.071552    0.063915    0.087891     0.081033
#
#                   type      year
# AveragePrice  0.615845  0.093197
# Total Volume -0.232434  0.017193
# PUC4046_sold -0.225819  0.003353
# PUC4225_sold -0.232289 -0.009559
# PUC4770_sold -0.210027 -0.036531
# Total Bags   -0.217788  0.071552
# Small Bags   -0.220535  0.063915
# Large Bags   -0.193177  0.087891
# XLarge Bags  -0.175483  0.081033
# type          1.000000 -0.000032
# year         -0.000032  1.000000

# %%
sns.heatmap(df.corr())

# %%
sns.lineplot(x='Total Volume',y='AveragePrice',data=df)

# %%
sns.lineplot(x='Total Volume',y='AveragePrice',data=df,hue='year')

# %%
sns.barplot(data=df, x="year", y="Total Volume", hue="type", palette=['blue', 'red'], saturation=0.6)

# %%
sns.barplot(data=df, x="year", y="AveragePrice", hue="type", palette=['blue', 'red'], saturation=0.6)

# %%
plt.scatter(df["AveragePrice"],df['Total Volume'])

# %%
sns.kdeplot(df["AveragePrice"], shade=True)

# %%
sns.kdeplot(df["Total Volume"], shade=True)

# %%
sns.kdeplot(df["type"], shade=True,label = "{} cyl".format(df["type"]))

# %%
for avacadotype in df["type"].unique():
    x = df["type"] == avacadotype
    sns.kdeplot(x, shade=True, label = "{} type".format(avacadotype))

# %%
d = df["type"].value_counts().to_dict()
plt.pie(d.values(),
       labels = d.keys(),
       autopct = '%1.1f%%', 
       textprops = {'fontsize': 10, 'color' : "white"} 
      )
# Out:
# ([<matplotlib.patches.Wedge at 0x1ef3c17db08>,
#   <matplotlib.patches.Wedge at 0x1ef3c1868c8>],
#  [Text(-0.00028404485245154447, 1.0999999633266004, '0'),
#   Text(0.0002840448524518983, -1.0999999633266004, '1')],
#  [Text(-0.00015493355588266062, 0.5999999799963274, '50.0%'),
#   Text(0.00015493355588285358, -0.5999999799963274, '50.0%')])

# %%
plt.plot(df["AveragePrice"], color = "red", alpha = .5)

# %%
df.columns
# Out:
# Index(['AveragePrice', 'Total Volume', 'PUC4046_sold', 'PUC4225_sold',
#        'PUC4770_sold', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags',
#        'type', 'year', 'region'],
#       dtype='object')

# %%
fig = plt.figure(figsize = (20,10))
ax = fig.add_subplot()
ax.plot(df["PUC4046_sold"], color = "red", alpha = .5)
ax.plot(df["PUC4225_sold"], color = "blue", alpha = .5)
ax.plot(df["PUC4770_sold"], color = "green", alpha = .5)
ax.tick_params(axis = 'x', labelsize = 10)
ax.tick_params(axis = 'y', labelsize = 10)

# %%
fig = plt.figure(figsize = (20,20))
ax = fig.add_subplot()
ax.plot(df["PUC4046_sold"],df["AveragePrice"], color = "red", alpha = .7,label='PUC4046')
ax.plot(df["PUC4225_sold"],df["AveragePrice"], color = "blue", alpha = .5,label='PUC4225')
ax.plot(df["PUC4770_sold"],df["AveragePrice"], color = "yellow", alpha = .9,label='PUC4770')
ax.legend()
